# %%
import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model = "llama-3.1-8b-instant")

response = model.invoke("Hello, how are you?")

print(response.content)
# Out:
# I'm functioning within normal parameters. How can I assist you today?

# %% [markdown]
# #### Types of Messages
# 1. System Message
# 2. Human Message
# 3. AI Message
# 4. Tool Message

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage, ToolMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write an poem on ML")
]

response = model.invoke(messages)

print(response.content)
# Out:
# In realms of code, where machines do play,
# A new era dawns, with wisdom's sway,
# Machine Learning, a marvel of might,
# Unfolds its secrets, in the digital light.
#
# With algorithms complex, and data vast,
# It weaves a tapestry, to forecast the past,
# Predicting trends, and unseen paths,
# A crystal ball, that gazes into the depths.
#
# Neural networks, like brain's intricate design,
# Process and learn, with each new find,
# Deep Learning's power, a symphony plays,
# As models evolve, in an endless maze.
#
# The curse of bias, a shadow cast,
# On datasets flawed, and past mistakes amassed,
# Yet still we strive, to make it right,
# To craft a future, where AI shines bright.
#
# In healthcare's realm, it diagnoses with ease,
# Aiding medical minds, in their expertise,
# In finance's world, it forecasts with guile,
# Aiding traders, to navigate life's trial.
#
# Through text and speech, it converses with us,
# A dialogue, that's natural, and not a fuss,
# Virtual assistants, a helping hand,
# A new era dawns, in a digital land.
#
# But as we harness, this power so grand,
# We must remember, its limitations and command,
# For in the machine, we must see our own,
# And ensure that ethics, are woven into the tone.
#
# A dance of human, and machine so fine,
# A harmony, where both can shine,
# In the realm of ML, a new world unfolds,
# A future bright, where wisdom is told.
